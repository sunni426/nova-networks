# %%
'''Running team 2

https://github.com/iseekwonderful/HPA-singlecell-2nd-dual-head-pipeline
https://www.kaggle.com/code/steamedsheep/hpa-final-submission-2-candidate-ii/notebook

'''
# !source novaenv/bin/activate
# %cd nova-networks/HPA-nova
# Out:
# /projectnb/btec-design3/novanetworks/nova-networks/HPA-nova
# /projectnb/btec-design3/novanetworks/novaenv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install pytorch-zoo@https://github.com/haoxusci/pytorch_zoo/archive/master.zip#sha256=38acc01279e42d1cf1dbde0cbfb43c72dcf4544e8e052dd13ecefe7b30425561
# !which python
# !pwd

import torch
# Making the code device-agnostic
# !source ../../novaenv/bin/activate
print(torch.backends.cudnn.enabled)
print(torch.cuda.is_available())
import os
print(os.getenv("CUDA_VISIBLE_DEVICES"))
torch.cuda.empty_cache()
# Out:
# /projectnb/btec-design3/novanetworks/novaenv/bin/python
# /projectnb/btec-design3/novanetworks/nova-networks/HPA-nova
# True
# True
# 1

# %%
# Calculate T test 
import pandas as pd
import scipy.stats as stats
import numpy as np
import pingouin as pg
import matplotlib.pyplot as plt

ground_truth1 = pd.read_csv('truth_1.csv')
prediction1 = pd.read_csv('pred_1.csv')
ground_truth2 = pd.read_csv('truth_2.csv')
prediction2 = pd.read_csv('pred_2.csv')
ground_truth3 = pd.read_csv('truth_3.csv')
prediction3 = pd.read_csv('pred_3.csv')
ground_truth4 = pd.read_csv('truth_4.csv')
prediction4 = pd.read_csv('pred_4.csv')
ground_truth5 = pd.read_csv('truth_5.csv')
prediction5 = pd.read_csv('pred_5.csv')


i = 0
j = 0
p1 = np.zeros(19)
p2 = np.zeros(19)
p3 = np.zeros(19)
p4 = np.zeros(19)
p5 = np.zeros(19)

for column in prediction1.columns[1:]:  # Skip the first column (ID)
    class_data = prediction1[column]
    gt_data = np.tile(ground_truth1[column],(1,10))
    gt_data = gt_data.T
    gt_data = gt_data.squeeze(1)

    t_statistic, p_value = stats.ttest_ind(gt_data, class_data, equal_var=False)
    print(f"Image 1: {column}")
    print(f"T-statistic: {t_statistic}")
    print(f"P-value: {p_value}")
    p_value = np.array(p_value)
    p1[i] = p_value
    i = i+1
    
    if p_value < 0.05:  # Assuming significance level of 0.05
        print("Reject null hypothesis: Means are different")
        j=j+1
    else:
        print("Fail to reject null hypothesis: Means are similar") # WE WANT THIS
    print("\n")

i = 0

for column in prediction2.columns[1:]:  # Skip the first column (ID)
    class_data = prediction2[column]
    gt_data = np.tile(ground_truth2[column],(1,10))
    gt_data = gt_data.T
    gt_data = gt_data.squeeze(1)

    t_statistic, p_value = stats.ttest_ind(gt_data, class_data, equal_var=False)
    print(f"Image 2: {column}")
    print(f"T-statistic: {t_statistic}")
    print(f"P-value: {p_value}")
    p_value = np.array(p_value)
    p2[i] = p_value
    allclass[i] = class_data
    i = i+1
    
    if p_value < 0.05:  # Assuming significance level of 0.05
        print("Reject null hypothesis: Means are different")
        j=j+1
    else:
        print("Fail to reject null hypothesis: Means are similar") # WE WANT THIS
    print("\n")


i = 0

for column in prediction3.columns[1:]:  # Skip the first column (ID)
    class_data = prediction3[column]
    gt_data = np.tile(ground_truth3[column],(1,10))
    gt_data = gt_data.T
    gt_data = gt_data.squeeze(1)

    t_statistic, p_value = stats.ttest_ind(gt_data, class_data, equal_var=False)
    print(f"Image 3: {column}")
    print(f"T-statistic: {t_statistic}")
    print(f"P-value: {p_value}")
    p_value = np.array(p_value)
    p3[i] = p_value
    allclass[i] = class_data
    i = i+1
    
    if p_value < 0.05:  # Assuming significance level of 0.05
        print("Reject null hypothesis: Means are different")
        j=j+1
    else:
        print("Fail to reject null hypothesis: Means are similar") # WE WANT THIS
    print("\n")


i = 0

for column in prediction4.columns[1:]:  # Skip the first column (ID)
    class_data = prediction4[column]
    gt_data = np.tile(ground_truth4[column],(1,10))
    gt_data = gt_data.T
    gt_data = gt_data.squeeze(1)

    t_statistic, p_value = stats.ttest_ind(gt_data, class_data, equal_var=False)
    print(f"Image 4: {column}")
    print(f"T-statistic: {t_statistic}")
    print(f"P-value: {p_value}")
    p_value = np.array(p_value)
    p4[i] = p_value
    allclass[i] = class_data
    i = i+1
    
    if p_value < 0.05:  # Assuming significance level of 0.05
        print("Reject null hypothesis: Means are different")
        j=j+1
    else:
        print("Fail to reject null hypothesis: Means are similar") # WE WANT THIS
    print("\n")


i = 0

for column in prediction5.columns[1:]:  # Skip the first column (ID)
    class_data = prediction5[column]
    gt_data = np.tile(ground_truth5[column],(1,10))
    gt_data = gt_data.T
    gt_data = gt_data.squeeze(1)

    t_statistic, p_value = stats.ttest_ind(gt_data, class_data, equal_var=False)
    print(f"Image 5: {column}")
    print(f"T-statistic: {t_statistic}")
    print(f"P-value: {p_value}")
    p_value = np.array(p_value)
    p5[i] = p_value
    i = i+1
    
    if p_value < 0.05:  # Assuming significance level of 0.05
        print("Reject null hypothesis: Means are different")
        j=j+1
    else:
        print("Fail to reject null hypothesis: Means are similar") # WE WANT THIS
    print("\n")

    
#print(f'p:{p}')
accuracy = j/19/5
print(f'accuracy:{1-accuracy}')
    

class_labels = range(0, 19)
plt.scatter(class_labels, p1, marker='o', color='red', label='Image 1')
plt.scatter(class_labels, p2, marker='o', color='blue', label='Image 2')
plt.scatter(class_labels, p3, marker='o', color='green', label='Image 3')
plt.scatter(class_labels, p4, marker='o', color='orange', label='Image 4')
plt.scatter(class_labels, p5, marker='o', color='purple', label='Image 5')

plt.title('P-values for 19 Classes from 5 Images')
plt.xlabel('Class')
plt.ylabel('P-value')
plt.legend()
plt.axhline(y=0.05, color='k', linestyle='--')
plt.xticks(class_labels)  # Set x-axis ticks to match class labels
plt.show()


# plt.boxplot(np.transpose(allclass), positions=np.arange(0, 19))
# plt.title('Box Plot for 19 Classes')
# plt.xlabel('Class')
# plt.ylabel('Prediction')


    # result = pg.ttest(class_data, gt_data, correction=True)
    # print(f"Class: {column}")
    # print(f"{result}")
    # p = result['p-val']
    
    # for p_value in p:
    #     if p_value < 0.05:
    #          print("Reject null hypothesis: Means are different")
    #     else:
    #         print("Fail to reject null hypothesis: Means are similar") # WE WANT THIS
    #     print("\n")
# Out:
# Image 1: class0
# T-statistic: -17.208604889885756
# P-value: 3.403750390861933e-08
# Reject null hypothesis: Means are different
#
#
# Image 1: class1
# T-statistic: -1.4886991428276388
# P-value: 0.17074622022653352
# Fail to reject null hypothesis: Means are similar
#
#
# Image 1: class2
# T-statistic: -5.635273845251044
# P-value: 0.00031954151352903007
# Reject null hypothesis: Means are different
#
#
# Image 1: class3
# T-statistic: -2.92209335070576
# P-value: 0.016973912795652857
# Reject null hypothesis: Means are different
#
#
# Image 1: class4
# T-statistic: 3.0539625813617386
# P-value: 0.013704777927367802
# Reject null hypothesis: Means are different
#
#
# Image 1: class5
# T-statistic: -3.616771841306075
# P-value: 0.005599862006753638
# Reject null hypothesis: Means are different
#
#
# Image 1: class6
# T-statistic: -1.3259805022590267
# P-value: 0.21751179408815718
# Fail to reject null hypothesis: Means are similar
#
#
# Image 1: class7
# T-statistic: -4.003410535828346
# P-value: 0.0030944676224931647
# Reject null hypothesis: Means are different
#
#
# Image 1: class8
# T-statistic: -1.8111009670483493
# P-value: 0.10355403358617632
# Fail to reject null hypothesis: Means are similar
#
#
# Image 1: class9
# T-statistic: -1.022954840896305
# P-value: 0.3330376168797351
# Fail to reject null hypothesis: Means are similar
#
#
# Image 1: class10
# T-statistic: -1.2222325715740001
# P-value: 0.252662864417782
# Fail to reject null hypothesis: Means are similar
#
#
# Image 1: class11
# T-statistic: nan
# P-value: nan
# Fail to reject null hypothesis: Means are similar
#
#
# Image 1: class12
# T-statistic: -2.5364036208478056
# P-value: 0.031898452496946034
# Reject null hypothesis: Means are different
#
#
# Image 1: class13
# T-statistic: -1.276899540905015
# P-value: 0.23359652344941806
# Fail to reject null hypothesis: Means are similar
#
#
# Image 1: class14
# T-statistic: -2.1785142413711296
# P-value: 0.0573130576578759
# Fail to reject null hypothesis: Means are similar
#
#
# Image 1: class15
# T-statistic: -1.4921910356063808
# P-value: 0.169846859015462
# Fail to reject null hypothesis: Means are similar
#
#
# Image 1: class16
# T-statistic: -1.675672535604049
# P-value: 0.12812138256380462
# Fail to reject null hypothesis: Means are similar
#
#
# Image 1: class17
# T-statistic: -2.372079824745522
# P-value: 0.04176635855686015
# Reject null hypothesis: Means are different
#
#
# Image 1: class18
# T-statistic: nan
# P-value: nan
# Fail to reject null hypothesis: Means are similar
#
#
# Image 2: class0
# T-statistic: 1.5567322391605114
# P-value: 0.15395950253340862
# Fail to reject null hypothesis: Means are similar
#
#
# Image 2: class1
# T-statistic: -1.3293831102305762
# P-value: 0.21643207344427257
# Fail to reject null hypothesis: Means are similar
#
#
# Image 2: class2
# T-statistic: -3.5090080855905135
# P-value: 0.006628950028924328
# Reject null hypothesis: Means are different
#
#
# Image 2: class3
# T-statistic: -2.613492066659489
# P-value: 0.02810932185251944
# Reject null hypothesis: Means are different
#
#
# Image 2: class4
# T-statistic: -2.1675176028556113
# P-value: 0.058348894826141216
# Fail to reject null hypothesis: Means are similar
#
#
# Image 2: class5
# T-statistic: -1.8487484116096693
# P-value: 0.09754502595851125
# Fail to reject null hypothesis: Means are similar
#
#
# Image 2: class6
# T-statistic: -2.444907036662984
# P-value: 0.03706508856594059
# Reject null hypothesis: Means are different
#
#
# Image 2: class7
# T-statistic: -1.8810696283632873
# P-value: 0.09264800959974653
# Fail to reject null hypothesis: Means are similar
#
#
# Image 2: class8
# T-statistic: -1.5786326863856148
# P-value: 0.1488766840492502
# Fail to reject null hypothesis: Means are similar
#
#
# Image 2: class9
# T-statistic: -1.7313851978837016
# P-value: 0.11742944392449878
# Fail to reject null hypothesis: Means are similar
#
#
# Image 2: class10
# T-statistic: -1.3381037073406898
# P-value: 0.21368548020723835
# Fail to reject null hypothesis: Means are similar
#
#
# Image 2: class11
# T-statistic: nan
# P-value: nan
# Fail to reject null hypothesis: Means are similar
#
#
# Image 2: class12
# T-statistic: -2.132635158357417
# P-value: 0.06175637601805737
# Fail to reject null hypothesis: Means are similar
#
#
# Image 2: class13
# T-statistic: -4.859863839681451
# P-value: 0.0008960020737715874
# Reject null hypothesis: Means are different
#
#
# Image 2: class14
# T-statistic: -3.0207927746165386
# P-value: 0.014460731307770997
# Reject null hypothesis: Means are different
#
#
# Image 2: class15
# T-statistic: -1.6353985147011696
# P-value: 0.13639499743525862
# Fail to reject null hypothesis: Means are similar
#
#
# Image 2: class16
# T-statistic: 2.927056352501574
# P-value: 0.01683742772145302
# Reject null hypothesis: Means are different
#
#
# Image 2: class17
# T-statistic: -1.3751380156609125
# P-value: 0.20234815125354672
# Fail to reject null hypothesis: Means are similar
#
#
# Image 2: class18
# T-statistic: nan
# P-value: nan
# Fail to reject null hypothesis: Means are similar
#
#
# Image 3: class0
# T-statistic: 1.2144947236793997
# P-value: 0.2554619377470138
# Fail to reject null hypothesis: Means are similar
#
#
# Image 3: class1
# T-statistic: -2.0439906365582816
# P-value: 0.07130349802009997
# Fail to reject null hypothesis: Means are similar
#
#
# Image 3: class2
# T-statistic: -3.668722596522352
# P-value: 0.005165074273512012
# Reject null hypothesis: Means are different
#
#
# Image 3: class3
# T-statistic: -3.131689218578375
# P-value: 0.012088758124221539
# Reject null hypothesis: Means are different
#
#
# Image 3: class4
# T-statistic: -1.9637005771536085
# P-value: 0.0811601651925774
# Fail to reject null hypothesis: Means are similar
#
#
# Image 3: class5
# T-statistic: 5.705528868307443
# P-value: 0.0002922554325814773
# Reject null hypothesis: Means are different
#
#
# Image 3: class6
# T-statistic: -1.6494578797505348
# P-value: 0.13345324502907022
# Fail to reject null hypothesis: Means are similar
#
#
# Image 3: class7
# T-statistic: -1.6168406963651174
# P-value: 0.14036772784380358
# Fail to reject null hypothesis: Means are similar
#
#
# Image 3: class8
# T-statistic: -1.1135879790206693
# P-value: 0.29431148737728685
# Fail to reject null hypothesis: Means are similar
#
#
# Image 3: class9
# T-statistic: -1.6186545632668983
# P-value: 0.13997487597516103
# Fail to reject null hypothesis: Means are similar
#
#
# Image 3: class10
# T-statistic: -1.055869951060155
# P-value: 0.3185455576568781
# Fail to reject null hypothesis: Means are similar
#
#
# Image 3: class11
# T-statistic: nan
# P-value: nan
# Fail to reject null hypothesis: Means are similar
#
#
# Image 3: class12
# T-statistic: -2.4666872431030873
# P-value: 0.03576412099394687
# Reject null hypothesis: Means are different
#
#
# Image 3: class13
# T-statistic: -1.0609232920295386
# P-value: 0.3163641045307152
# Fail to reject null hypothesis: Means are similar
#
#
# Image 3: class14
# T-statistic: -1.6424271343060504
# P-value: 0.13491708478677034
# Fail to reject null hypothesis: Means are similar
#
#
# Image 3: class15
# T-statistic: -1.8551919814767401
# P-value: 0.09654980000630314
# Fail to reject null hypothesis: Means are similar
#
#
# Image 3: class16
# T-statistic: -2.0894072515594817
# P-value: 0.06624699425142692
# Fail to reject null hypothesis: Means are similar
#
#
# Image 3: class17
# T-statistic: -1.5083096917154695
# P-value: 0.16574915648037827
# Fail to reject null hypothesis: Means are similar
#
#
# Image 3: class18
# T-statistic: nan
# P-value: nan
# Fail to reject null hypothesis: Means are similar
#
#
# Image 4: class0
# T-statistic: 4.529356060962373
# P-value: 0.0014275138667111278
# Reject null hypothesis: Means are different
#
#
# Image 4: class1
# T-statistic: -3.2529542456927167
# P-value: 0.009950230896716731
# Reject null hypothesis: Means are different
#
#
# Image 4: class2
# T-statistic: -2.243072304468236
# P-value: 0.05158375494240355
# Fail to reject null hypothesis: Means are similar
#
#
# Image 4: class3
# T-statistic: 1.9264034355371635
# P-value: 0.08616784522082051
# Fail to reject null hypothesis: Means are similar
#
#
# Image 4: class4
# T-statistic: -2.5445428998752813
# P-value: 0.03147529968259566
# Reject null hypothesis: Means are different
#
#
# Image 4: class5
# T-statistic: -2.5647328205112223
# P-value: 0.030449778024228914
# Reject null hypothesis: Means are different
#
#
# Image 4: class6
# T-statistic: -1.5092609284165546
# P-value: 0.16551007649604096
# Fail to reject null hypothesis: Means are similar
#
#
# Image 4: class7
# T-statistic: -2.2924217727726868
# P-value: 0.04758575705355568
# Reject null hypothesis: Means are different
#
#
# Image 4: class8
# T-statistic: -1.2155114231864181
# P-value: 0.2550927219011771
# Fail to reject null hypothesis: Means are similar
#
#
# Image 4: class9
# T-statistic: -1.611634906530529
# P-value: 0.141500733485278
# Fail to reject null hypothesis: Means are similar
#
#
# Image 4: class10
# T-statistic: 3.3453006050120107
# P-value: 0.00858746890657223
# Reject null hypothesis: Means are different
#
#
# Image 4: class11
# T-statistic: -1.0
# P-value: 0.34343639613791355
# Fail to reject null hypothesis: Means are similar
#
#
# Image 4: class12
# T-statistic: -3.636120821985172
# P-value: 0.005433592579847347
# Reject null hypothesis: Means are different
#
#
# Image 4: class13
# T-statistic: -1.9818461384765969
# P-value: 0.0788249751852392
# Fail to reject null hypothesis: Means are similar
#
#
# Image 4: class14
# T-statistic: -1.2966083449818429
# P-value: 0.2270220327611407
# Fail to reject null hypothesis: Means are similar
#
#
# Image 4: class15
# T-statistic: nan
# P-value: nan
# Fail to reject null hypothesis: Means are similar
#
#
# Image 4: class16
# T-statistic: -3.907804409206709
# P-value: 0.0035766793109869993
# Reject null hypothesis: Means are different
#
#
# Image 4: class17
# T-statistic: -1.1310946398684936
# P-value: 0.28725389636419757
# Fail to reject null hypothesis: Means are similar
#
#
# Image 4: class18
# T-statistic: nan
# P-value: nan
# Fail to reject null hypothesis: Means are similar
#
#
# Image 5: class0
# T-statistic: -4.674848940960924
# P-value: 0.0011606145132170155
# Reject null hypothesis: Means are different
#
#
# Image 5: class1
# T-statistic: -1.1093728453669471
# P-value: 0.296030991135624
# Fail to reject null hypothesis: Means are similar
#
#
# Image 5: class2
# T-statistic: -2.0949179371252913
# P-value: 0.06565746805064274
# Fail to reject null hypothesis: Means are similar
#
#
# Image 5: class3
# T-statistic: -1.530903598751062
# P-value: 0.1601521441365485
# Fail to reject null hypothesis: Means are similar
#
#
# Image 5: class4
# T-statistic: -1.5077040365638104
# P-value: 0.16590153799920512
# Fail to reject null hypothesis: Means are similar
#
#
# Image 5: class5
# T-statistic: -3.4752715871157416
# P-value: 0.006990442661842282
# Reject null hypothesis: Means are different
#
#
# Image 5: class6
# T-statistic: -1.9166612306646642
# P-value: 0.08752326754563063
# Fail to reject null hypothesis: Means are similar
#
#
# Image 5: class7
# T-statistic: -2.524808891456856
# P-value: 0.03251110923630829
# Reject null hypothesis: Means are different
#
#
# Image 5: class8
# T-statistic: -3.546306369127464
# P-value: 0.006251980550795533
# Reject null hypothesis: Means are different
#
#
# Image 5: class9
# T-statistic: 8.052382140272824
# P-value: 2.100944321881718e-05
# Reject null hypothesis: Means are different
#
#
# Image 5: class10
# T-statistic: -1.6840849768639787
# P-value: 0.12645189194571982
# Fail to reject null hypothesis: Means are similar
#
#
# Image 5: class11
# T-statistic: -1.7098311599677771
# P-value: 0.1214650662430908
# Fail to reject null hypothesis: Means are similar
#
#
# Image 5: class12
# T-statistic: -6.071744430029032
# P-value: 0.0001855059012253839
# Reject null hypothesis: Means are different
#
#
# Image 5: class13
# T-statistic: 2.9908827001682816
# P-value: 0.015179166835951167
# Reject null hypothesis: Means are different
#
#
# Image 5: class14
# T-statistic: -2.587169721675747
# P-value: 0.029349410599249566
# Reject null hypothesis: Means are different
#
#
# Image 5: class15
# T-statistic: -1.2191678755212052
# P-value: 0.25376847160229604
# Fail to reject null hypothesis: Means are similar
#
#
# Image 5: class16
# T-statistic: -10.78724209380562
# P-value: 1.8977978870532681e-06
# Reject null hypothesis: Means are different
#
#
# Image 5: class17
# T-statistic: -2.4827527468383983
# P-value: 0.034833759045785
# Reject null hypothesis: Means are different
#
#
# Image 5: class18
# T-statistic: nan
# P-value: nan
# Fail to reject null hypothesis: Means are similar
#
#
# accuracy:0.6210526315789474
# /projectnb/btec-design3/novanetworks/novaenv/lib/python3.10/site-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
